# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/leandrohmvieira/Machine-Learning-SOA-POC/blob/master/resnet34.ipynb)

# %%
#install pytorch
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
#install fast.ai deep learning library
# !pip install fastai
# !pip install -U numpy
# !pip install -U pillow
# !pip install -U scipy

# %%
#import fast.ai modules
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
#download dataset
import tarfile

# !wget http://data.vision.ee.ethz.ch/cvl/fashion-data.tar.bz2

tar = tarfile.open("fashion-data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

# %%
#make some ajustments to data,

# %%
PATH = "fashion-data/"
sz = 224

# %%
os.listdir(PATH)
# Out:
# ['train.txt', 'readme.txt', 'images', 'labels.json', 'test.txt']

# %%
os.listdir(f'{PATH}images')
# Out:
# ['6',
#  '7',
#  '9',
#  '1',
#  '13',
#  '5',
#  '3',
#  '0',
#  '8',
#  '12',
#  '2',
#  '14',
#  '4',
#  '11',
#  '10']

# %%
files = os.listdir(f'{PATH}images/0/n04197391_blouse')[:5]
files
# Out:
# ['n04197391_14941_0.jpg',
#  'n04197391_272_0.jpg',
#  'n04197391_796_0.jpg',
#  'n04197391_1512_0.jpg',
#  'n04197391_5906_0.jpg']

# %%
img = plt.imread(f'{PATH}images/0/n04197391_blouse/{files[0]}')
plt.imshow(img);

# %%
img.shape
# Out:
# (204, 142, 3)

# %%
arch=resnet34
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz), trn_name='images')
learn = ConvLearner.pretrained(arch, data, precompute=True)
learn.fit(0.01, 2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-e2a5d69401e3> in <module>()
#       1 arch=resnet34
# ----> 2 data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz), trn_name='images')
#       3 learn = ConvLearner.pretrained(arch, data, precompute=True)
#       4 learn.fit(0.01, 2)
#
# /usr/local/lib/python3.6/dist-packages/fastai/dataset.py in from_paths(cls, path, bs, tfms, trn_name, val_name, test_name, test_with_labels, num_workers)
#     428         """
#     429         assert not(tfms[0] is None or tfms[1] is None), "please provide transformations for your train and validation sets"
# --> 430         trn,val = [folder_source(path, o) for o in (trn_name, val_name)]
#     431         if test_name:
#     432             test = folder_source(path, test_name) if test_with_labels else read_dir(path, test_name)
#
# ...

# %%
ImageClassifierData.from_paths?
